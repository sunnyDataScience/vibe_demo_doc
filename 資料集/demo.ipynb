# %%
import pandas as pd

# %%
df = pd.read_csv('/home/os-sunnie.gd.weng/python_workstation/side-project/vibe_coding_workshop-main/資料集/SuperMarket Analysis.csv')

# %%
df

# 只針對類別型欄位，列出每個欄位的所有類別
for col in df.select_dtypes(include='object').columns:
    print(f"欄位：{col}")
    print(df[col].unique())
    print("-" * 30)
# Out:
# 欄位：Invoice ID
# ['750-67-8428' '226-31-3081' '631-41-3108' '123-19-1176' '373-73-7910'
#  '699-14-3026' '355-53-5943' '315-22-5665' '665-32-9167' '692-92-5582'
#  '351-62-0822' '529-56-3974' '365-64-0515' '252-56-2699' '829-34-3910'
#  '299-46-1805' '656-95-9349' '765-26-6951' '329-62-1586' '319-50-3348'
#  '300-71-4605' '371-85-5789' '273-16-6619' '636-48-8204' '549-59-1358'
#  '227-03-5010' '649-29-6775' '189-17-4241' '145-94-9061' '848-62-7243'
#  '871-79-8483' '149-71-6266' '640-49-2076' '595-11-5460' '183-56-6882'
#  '232-16-2483' '129-29-8530' '272-65-1806' '333-73-7901' '777-82-7220'
#  '280-35-5823' '554-53-8700' '354-25-5821' '228-96-1411' '617-15-4209'
#  '132-32-9879' '370-41-7321' '727-46-3608' '669-54-1719' '574-22-5561'
#  '326-78-5178' '162-48-8011' '616-24-2851' '778-71-5554' '242-55-6721'
#  '399-46-5918' '106-35-6779' '635-40-6220' '817-48-8732' '120-06-4233'
#  '285-68-5083' '803-83-5989' '347-34-2234' '199-75-8169' '853-23-2453'
# ...

# %%
df = pd.read_csv('/home/os-sunnie.gd.weng/python_workstation/side-project/vibe_coding_workshop-main/資料集/Taiwan_Enhanced_SuperMarket_Sales.csv')

# %%
df.head()
# Out:
#     Invoice ID        Date      Time Shopping_Period Store_Name Branch  \
# 0  750-67-8428  2019-01-05  13:08:00              午餐      全聯板橋店     全聯
# 1  226-31-3081  2019-03-08  10:29:00              早晨     大潤發古亭店    大潤發
# 2  631-41-3108  2019-03-03  13:23:00              午餐      全聯三重店     全聯
# 3  123-19-1176  2019-01-27  20:33:00              夜間     美廉社板橋店    美廉社
# 4  373-73-7910  2019-02-08  10:37:00              早晨      全聯忠孝店     全聯
#
#   Store_Size City Customer type Membership_Level  ... Quantity  Tax 5%  \
# 0         中型  新北市        Member             銀卡會員  ...        7  784.25
# 1         大型  台北市        Member             一般會員  ...        5  106.69
# 2         中型  高雄市        Member             銀卡會員  ...        7  486.46
# 3         小型  台南市        Member             一般會員  ...        8  645.54
# 4         中型  高雄市        Member             一般會員  ...        7  906.25
#
#       Sales  Payment      cogs  gross margin percentage  gross income Rating  \
# ...

# %%
df

# 只針對類別型欄位，列出每個欄位的所有類別
for col in df.select_dtypes(include='object').columns:
    print(f"欄位：{col}")
    print(df[col].unique())
    print("-" * 30)
# Out:
# 欄位：Invoice ID
# ['750-67-8428' '226-31-3081' '631-41-3108' '123-19-1176' '373-73-7910'
#  '699-14-3026' '355-53-5943' '315-22-5665' '665-32-9167' '692-92-5582'
#  '351-62-0822' '529-56-3974' '365-64-0515' '252-56-2699' '829-34-3910'
#  '299-46-1805' '656-95-9349' '765-26-6951' '329-62-1586' '319-50-3348'
#  '300-71-4605' '371-85-5789' '273-16-6619' '636-48-8204' '549-59-1358'
#  '227-03-5010' '649-29-6775' '189-17-4241' '145-94-9061' '848-62-7243'
#  '871-79-8483' '149-71-6266' '640-49-2076' '595-11-5460' '183-56-6882'
#  '232-16-2483' '129-29-8530' '272-65-1806' '333-73-7901' '777-82-7220'
#  '280-35-5823' '554-53-8700' '354-25-5821' '228-96-1411' '617-15-4209'
#  '132-32-9879' '370-41-7321' '727-46-3608' '669-54-1719' '574-22-5561'
#  '326-78-5178' '162-48-8011' '616-24-2851' '778-71-5554' '242-55-6721'
#  '399-46-5918' '106-35-6779' '635-40-6220' '817-48-8732' '120-06-4233'
#  '285-68-5083' '803-83-5989' '347-34-2234' '199-75-8169' '853-23-2453'
# ...
